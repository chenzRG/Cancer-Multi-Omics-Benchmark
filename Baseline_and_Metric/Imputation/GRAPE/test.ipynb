# %%
import pandas as pd

# %%
name = 'BCRA'
#name = 'COAD'
#name = 'GBM'
#name = 'LGG'
#name = 'OV'

# %%
df_np = pd.read_csv( './uci/raw_data/{}/data.csv'.format(name), skiprows=1)

# %%
df_np
# Out:
#            A1BG  1.38992680782218  1.5228724840075  1.78827053079654  \
# 0      A1BG.AS1          0.436758         1.815091          0.580557
# 1           A2M         -0.876187        -0.508085         -0.258138
# 2       A2M.AS1          1.607818         0.863019         -0.491954
# 3         A2ML1         -0.415138        -0.406608         -0.455969
# 4         A2MP1         -0.374641        -0.361230          0.855983
# ...         ...               ...              ...               ...
# 18200    ZYG11A          1.753777         1.298863          2.105007
# 18201    ZYG11B          2.013674        -0.140439         -0.334864
# 18202       ZYX         -0.424991         0.635518          0.573943
# 18203     ZZEF1          1.214399         0.302547         -0.379244
# 18204      ZZZ3          1.667340        -1.162286         -0.547104
#
#        -0.28854318434778  -0.462679821242539  -0.451169373048028  \
# 0              -0.250194           -0.091285           -0.688598
# ...

# %%
df_np = df_np.drop(df_np.columns[0], axis=1)
df_np
# Out:
#        1.38992680782218  1.5228724840075  1.78827053079654  -0.28854318434778  \
# 0              0.436758         1.815091          0.580557          -0.250194
# 1             -0.876187        -0.508085         -0.258138          -0.030804
# 2              1.607818         0.863019         -0.491954          -0.579638
# 3             -0.415138        -0.406608         -0.455969          -0.464938
# 4             -0.374641        -0.361230          0.855983          -0.313092
# ...                 ...              ...               ...                ...
# 18200          1.753777         1.298863          2.105007           0.916528
# 18201          2.013674        -0.140439         -0.334864          -0.278901
# 18202         -0.424991         0.635518          0.573943           0.515520
# 18203          1.214399         0.302547         -0.379244          -0.939663
# 18204          1.667340        -1.162286         -0.547104           0.057166
#
# ...

# %%
df_np = pd.read_csv('./uci/raw_data/{}/data.csv'.format(name), skiprows=1)

df_np = df_np.drop(df_np.columns[0], axis=1)

df_np = df_np.iloc[:3000,:]

df_np.to_csv('./uci/raw_data/{}/processed_data.csv'.format(name), index=False)
